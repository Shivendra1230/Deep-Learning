# %%
import numpy as np 
import pandas as pd 
import time # time module for measuring execution time

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X= df.iloc[:,0:2]
y= df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler # min max  scaling used to scale the data
# where as standard scaler is used to standardize the data by removing the mean and scaling to unit variance
scaler= StandardScaler()
X_scaled= scaler.fit_transform(X) # fit_transform is used to fit the scaler to the data and then transform the data

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# c:\Users\utyo1\anaconda3\envs\ml\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start_time = time.time() # start time of the training
history = model.fit(X_scaled,y,epochs=100,batch_size=1,validation_split=0.2)# verbose is used to control the amount of information displayed during training.
print(time.time() - start_time) # end time of the training
# Out:
# Epoch 1/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7250 - loss: 0.5027 - val_accuracy: 0.5625 - val_loss: 0.6301
# Epoch 2/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8125 - loss: 0.3659 - val_accuracy: 0.8625 - val_loss: 0.5369
# Epoch 3/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8562 - loss: 0.3235 - val_accuracy: 0.9125 - val_loss: 0.4651
# Epoch 4/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8656 - loss: 0.2983 - val_accuracy: 0.9250 - val_loss: 0.4064
# Epoch 5/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - accuracy: 0.8687 - loss: 0.2843 - val_accuracy: 0.9375 - val_loss: 0.3553
# Epoch 6/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8687 - loss: 0.2746 - val_accuracy: 0.9500 - val_loss: 0.3181
# Epoch 7/100
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.8750 - loss: 0.2716 - val_accuracy: 0.9500 - val_loss: 0.2884
# Epoch 8/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=250,validation_split=0.2)
print(time.time() - start)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.1937 - loss: 0.7507 - val_accuracy: 0.5375 - val_loss: 0.7522
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2562 - loss: 0.7369 - val_accuracy: 0.4250 - val_loss: 0.7517
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4062 - loss: 0.7271 - val_accuracy: 0.3875 - val_loss: 0.7505
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5875 - loss: 0.7198 - val_accuracy: 0.3750 - val_loss: 0.7490
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6375 - loss: 0.7133 - val_accuracy: 0.3625 - val_loss: 0.7490
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6781 - loss: 0.7071 - val_accuracy: 0.3625 - val_loss: 0.7492
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7125 - loss: 0.7010 - val_accuracy: 0.3625 - val_loss: 0.7482
# Epoch 8/10
# ...

# %%
plt.plot(history.history['loss'])

# %%
# Batch gradient descent is a variant of gradient descent where the model is trained on the entire dataset at once. This can be more efficient than training on individual samples, but it can also be more prone to overfitting. In this case, we are using a batch size of 250, which means that the model will be trained on 250 samples at a time.
# the time taken to train the model with batch gradient descent is significantly less than the time taken to train the model with stochastic gradient descent. This is because the model is trained on the entire dataset at once, rather than on individual samples. However, batch gradient descent can be more prone to overfitting, as the model may learn to memorize the training data rather than generalize to new data.
# covergence of the model is also faster with batch gradient descent, as the model is able to learn from the entire dataset at once. However, it is important to note that batch gradient descent may not always be the best choice for training a model, as it can be more prone to overfitting and may not always converge to the optimal solution.
# we use mini batch gradient descent, which is a compromise between stochastic and batch gradient descent. In mini batch gradient descent, the model is trained on small batches of data, rather than on individual samples or the entire dataset. This can help to reduce overfitting and improve convergence, while still allowing the model to learn from the entire dataset. In this case, we are using a batch size of 32, which means that the model will be trained on 32 samples at a time.
